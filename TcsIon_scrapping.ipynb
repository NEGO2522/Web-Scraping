# %% [markdown]
# ## Tcs Ion Scrapping Data

# %%
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.tcsion.com/home")

# %%
web.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(web.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <!-- Page Title -->
#   <title>
#    TCS iON – A One-stop Platform for Learners and Institutions
#   </title>
#   <!-- Canonical Tag -->
#   <link href="#" rel="canonical"/>
#   <link href="https://www.tcsion.com/dotcom/ICMP/TCSiON-favicon.png" rel="icon" sizes="16x16" type="image/svg"/>
#   <link href="https://www.tcsion.com/dotcom/ICMP/TCSiON-favicon.png" rel="apple-touch-icon"/>
#   <link href="https://www.tcsion.com/dotcom/ICMP/TCSiON-favicon.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://www.tcsion.com/dotcom/ICMP/TCSiON-favicon.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.tcsion.com/dotcom/ICMP/TCSiON-favicon.png" rel="apple-touch-icon" sizes="144x144"/>
# ...

# %%
soup.find_all("p")
# Out:
# [<p id="text2">Transform learning with <br/>
#             Educational Games</p>,
#  <p>Test Date:</p>,
#  <p>Apply before:</p>,
#  <p id="text2">Inspire students to become<br/>
#             SDG Ambassadors!</p>,
#  <p>You will see personalised recommendations here</p>,
#  <p>Explore courses that are in demand</p>,
#  <p>Get access to best-in-class, secured and seamless cloud-based solutions</p>,
#  <p>Discover a collaborative pedagogical model to enrich participatory learning</p>,
#  <p>Conduct fun and interactive assessments using digital tools</p>,
#  <p>Assess anywhere and anytime to improve efficiency and the speed of subjective answer script evaluation</p>,
#  <p>Manage traditional and non-traditional academic programs, unite and automate business processes</p>,
#  <p>TCS iON Digital Exams enable digitisation and automation of the exam processes</p>,
# ...

# %%
soup.find_all("h2")
# Out:
# [<h2 class="IIMVizagBanner" id="head9">Get Certified from IIM Vizag and head towards an excellent career in Integrated Operations and Supply Chain Management</h2>,
#  <h2 id="head2">Ed-Games Hub</h2>,
#  <h2 class="" id="head9">Boost Your Job Readiness<br/>
#             Unlock a FREE 4-in-1 Pack with<br/>
#             TCS iON NQT</h2>,
#  <h2 class="" id="head9">Certificate Programme in <br/>
#             Cyber Security by IIT Ropar</h2>,
#  <h2 class="" id="head9">Redefine Learning and Boost Your Career with TCS iON</h2>,
#  <h2 class="" id="head9">Find Your Perfect Career Path with <br/>
#             TCS iON Career Insight</h2>,
#  <h2 id="head2">Team SDG Universe</h2>,
#  <h2>We would like to know you better</h2>,
#  <h2>Courses for learners</h2>,
#  <h2>Offerings for institutions</h2>,
#  <h2>TCS iON<br/>
#                   Digital Learning</h2>,
#  <h2>TCS iON<br/>
#                   Digital Assessments</h2>,
#  <h2>TCS iON<br/>
#                   Digital Marking</h2>,
# ...

# %%
soup.find_all("img")
# Out:
# [<img alt="TCS iON Digital Learning" src="/per/g01/pub/1016/iDH/webpresence/extractedtemplates/TCSiON/HomeTemplate/images/institutions-courses/img01.webp" title="TCS iON Digital Learning"/>,
#  <img alt="TCS iON Digital Assessments" src="/per/g01/pub/1016/iDH/webpresence/extractedtemplates/TCSiON/HomeTemplate/images/institutions-courses/img02.webp" title="TCS iON Digital Assessments"/>,
#  <img alt="TCS iON Digital Marking" src="/per/g01/pub/1016/iDH/webpresence/extractedtemplates/TCSiON/HomeTemplate/images/institutions-courses/img03.webp" title="TCS iON Digital Marking"/>,
#  <img alt="TCS iON Digital Campus" src="/per/g01/pub/1016/iDH/webpresence/extractedtemplates/TCSiON/HomeTemplate/images/institutions-courses/img04.webp" title="TCS iON Digital Campus"/>,
#  <img alt="TCS iON Digital Exam" src="/per/g01/pub/1016/iDH/webpresence/extractedtemplates/TCSiON/HomeTemplate/images/institutions-courses/digital-exams.webp" title="TCS iON Digital Exam"/>,
# ...

# %%
soup.find_all("a")
# Out:
# [<a class="tcs-primary-btn" href="/hub/iim-vizag-certificate-program/integrated-operations-and-supply-chain-management" id="anc2" title="Register Now">Register Now</a>,
#  <a class="tcs-primary-btn" href="/hub/ed-games/" id="anc2" title="Try Now">Try Now</a>,
#  <a class="tcs-primary-btn" href="/hub/national-qualifier-test/" id="anc2" title="Know More">Know More</a>,
#  <a class="tcs-primary-btn" href="/hub/iit-ropar-certificate-program/cyber-security/" id="anc2" title="Buy Now">Buy Now</a>,
#  <a class="tcs-primary-btn" href="/iDH/India/Catalog/order_by/popular_down/pageNo/1" id="anc2" title="Know More">Know More</a>,
#  <a class="tcs-primary-btn" href="https://iur.ls/D/1S48PV4" id="anc2" title="Explore Now">Explore Now</a>,
#  <a class="tcs-primary-btn" href="/hub/team-sdg-universe/" id="anc2" title="Join Now">Join Now</a>,
#  <a href="#"> <i class="pl-icon">
#  <svg viewbox="0 0 200 200">
# ...

# %%
soup.get_text()
print(soup.get_text())
# Out:
# TCS iON – A One-stop Platform for Learners and Institutions
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Get Certified from IIM Vizag and head towards an excellent career in Integrated Operations and Supply Chain Management
#
#  Register Now
#
#
#
#
#
#
#
#
# Ed-Games Hub
# Transform learning with
#            Educational Games
#
#  Try Now
#
#
#
#
#
#
#
# Boost Your Job Readiness
#            Unlock a FREE 4-in-1 Pack with
#            TCS iON NQT
#
#
# Test Date:
# 12th May, 2025(For May Exam)
#
# Apply before:
# 30th April, 2025(For May Exam)
#
#
#  Know More
#
#
#
#
#
#
#
# Certificate Programme in
#            Cyber Security by IIT Ropar
#
#  Buy Now
#
#
#
#
#
#
#
# Redefine Learning and Boost Your Career with TCS iON
#
#  Know More
#
#
#
#
#
#
#
# Find Your Perfect Career Path with
#            TCS iON Career Insight
#
#  Explore Now
#
#
#
#
#
#
#
#
# Team SDG Universe
# Inspire students to become
#            SDG Ambassadors!
#
# ...
